# %%
import pandas as pd

candidate_paths = ["data/dataset.csv", "../data/dataset.csv"]
df = None
data_path = None

for path in candidate_paths:
    try:
        df = pd.read_csv(path)
        data_path = path
        break
    except FileNotFoundError:
        continue

if data_path is None:
    raise FileNotFoundError("Could not find data/dataset.csv from the current notebook working directory.")

print(df.head())
# Out:
#    fever  cough  fatigue  headache  body_pain  breathing_difficulty  bp_level  \
# 0      1      1        1         1          1                     0       120
# 1      1      1        1         0          1                     0       118
# 2      1      0        1         1          1                     0       122
# 3      0      1        1         0          0                     0       115
# 4      0      1        0         0          0                     0       110
#
#    glucose_level disease
# 0             90     Flu
# 1             85     Flu
# 2             88     Flu
# 3             80    Cold
# 4             78    Cold
